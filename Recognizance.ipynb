# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train = pd.read_csv('./train_data.csv')
df_test = pd.read_csv('./test_data.csv')

# %%
df_test
# Out:
#               Datetime  Temperature  Humidity  Zephyr  GeneralDiffuseFlows  \
# 0      9/12/2017 19:00       23.510     50.15   0.271               46.780
# 1      9/12/2017 19:20       22.970     52.65   0.273                9.520
# 2      9/12/2017 19:40       22.730     53.68   0.271                1.257
# 3      9/12/2017 20:00       22.370     54.65   0.269                0.080
# 4      9/12/2017 20:20       22.070     55.85   0.274                0.080
# ...                ...          ...       ...     ...                  ...
# 7858  12/30/2017 22:20        7.650     70.10   0.081                0.062
# 7859  12/30/2017 22:40        7.390     71.20   0.079                0.066
# 7860  12/30/2017 23:00        7.070     72.50   0.080                0.059
# 7861  12/30/2017 23:20        6.947     72.60   0.082                0.051
# 7862  12/30/2017 23:40        6.758     73.00   0.080                0.066
#
#       DiffuseFlows
# 0           49.950
# 1            7.830
# ...

# %%
df_train
# Out:
#               Datetime  Temperature  Humidity  Zephyr  GeneralDiffuseFlows  \
# 0        1/1/2017 0:00        6.559     73.80   0.083                0.051
# 1        1/1/2017 0:20        6.313     74.50   0.080                0.062
# 2        1/1/2017 0:40        5.921     75.70   0.081                0.048
# 3        1/1/2017 1:00        5.641     77.70   0.080                0.048
# 4        1/1/2017 1:20        5.678     78.10   0.081                0.066
# ...                ...          ...       ...     ...                  ...
# 18340  9/12/2017 17:20       25.410     43.21   0.276              342.200
# 18341  9/12/2017 17:40       25.500     42.95   0.273              295.900
# 18342  9/12/2017 18:00       24.980     44.61   0.272              237.400
# 18343  9/12/2017 18:20       24.430     46.22   0.273              102.700
# 18344  9/12/2017 18:40       23.970     48.12   0.270              112.800
#
#        DiffuseFlows  PowerConsumption
# ...

# %%
new_col = []
for date in df_train['Datetime']:
    new_col.append(date.strip().split(' ')[1])

# %%
new_col_t = []
for date in df_test['Datetime']:
    new_col_t.append(date.strip().split(' ')[1])

# %%
new_col_t
# Out:
# ['19:00',
#  '19:20',
#  '19:40',
#  '20:00',
#  '20:20',
#  '20:40',
#  '21:00',
#  '21:20',
#  '21:40',
#  '22:00',
#  '22:20',
#  '22:40',
#  '23:00',
#  '23:20',
#  '23:40',
#  '0:00',
#  '0:20',
#  '0:40',
#  '1:00',
#  '1:20',
#  '1:40',
#  '2:00',
#  '2:20',
#  '2:40',
#  '3:00',
#  '3:20',
#  '3:40',
#  '4:00',
#  '4:20',
#  '4:40',
#  '5:00',
#  '5:20',
#  '5:40',
#  '6:00',
#  '6:20',
#  '6:40',
#  '7:00',
#  '7:20',
#  '7:40',
#  '8:00',
#  '8:20',
#  '8:40',
#  '9:00',
#  '9:20',
#  '9:40',
#  '10:00',
#  '10:20',
#  '10:40',
#  '11:00',
#  '11:20',
#  '11:40',
#  '12:00',
#  '12:20',
#  '12:40',
#  '13:00',
#  '13:20',
#  '13:40',
#  '14:00',
#  '14:20',
#  '14:40',
#  '15:00',
#  '15:20',
#  '15:40',
#  '16:00',
#  '16:20',
#  '16:40',
#  '17:00',
#  '17:20',
#  '17:40',
#  '18:00',
#  '18:20',
#  '18:40',
#  '19:00',
#  '19:20',
#  '19:40',
#  '20:00',
#  '20:20',
#  '20:40',
#  '21:00',
#  '21:20',
#  '21:40',
#  '22:00',
#  '22:20',
#  '22:40',
#  '23:00',
# ...

# %%
import math

# %%
new_col2 = []
for hour in new_col:
    new_col2.append(int(hour.split(':')[0]) + int(hour.split(':')[1])/60.0)

# %%
new_col_t2 = []
for hour in new_col_t:
    new_col_t2.append(int(hour.split(':')[0]) + int(hour.split(':')[1])/60.0)

# %%
new_col_t2
# Out:
# [19.0,
#  19.333333333333332,
#  19.666666666666668,
#  20.0,
#  20.333333333333332,
#  20.666666666666668,
#  21.0,
#  21.333333333333332,
#  21.666666666666668,
#  22.0,
#  22.333333333333332,
#  22.666666666666668,
#  23.0,
#  23.333333333333332,
#  23.666666666666668,
#  0.0,
#  0.3333333333333333,
#  0.6666666666666666,
#  1.0,
#  1.3333333333333333,
#  1.6666666666666665,
#  2.0,
#  2.3333333333333335,
#  2.6666666666666665,
#  3.0,
#  3.3333333333333335,
#  3.6666666666666665,
#  4.0,
#  4.333333333333333,
#  4.666666666666667,
#  5.0,
#  5.333333333333333,
#  5.666666666666667,
#  6.0,
#  6.333333333333333,
#  6.666666666666667,
#  7.0,
#  7.333333333333333,
#  7.666666666666667,
#  8.0,
#  8.333333333333334,
#  8.666666666666666,
#  9.0,
#  9.333333333333334,
#  9.666666666666666,
#  10.0,
#  10.333333333333334,
#  10.666666666666666,
#  11.0,
#  11.333333333333334,
#  11.666666666666666,
#  12.0,
#  12.333333333333334,
#  12.666666666666666,
#  13.0,
#  13.333333333333334,
# ...

# %%
new_col_t2
# Out:
# [19.0,
#  19.333333333333332,
#  19.666666666666668,
#  20.0,
#  20.333333333333332,
#  20.666666666666668,
#  21.0,
#  21.333333333333332,
#  21.666666666666668,
#  22.0,
#  22.333333333333332,
#  22.666666666666668,
#  23.0,
#  23.333333333333332,
#  23.666666666666668,
#  0.0,
#  0.3333333333333333,
#  0.6666666666666666,
#  1.0,
#  1.3333333333333333,
#  1.6666666666666665,
#  2.0,
#  2.3333333333333335,
#  2.6666666666666665,
#  3.0,
#  3.3333333333333335,
#  3.6666666666666665,
#  4.0,
#  4.333333333333333,
#  4.666666666666667,
#  5.0,
#  5.333333333333333,
#  5.666666666666667,
#  6.0,
#  6.333333333333333,
#  6.666666666666667,
#  7.0,
#  7.333333333333333,
#  7.666666666666667,
#  8.0,
#  8.333333333333334,
#  8.666666666666666,
#  9.0,
#  9.333333333333334,
#  9.666666666666666,
#  10.0,
#  10.333333333333334,
#  10.666666666666666,
#  11.0,
#  11.333333333333334,
#  11.666666666666666,
#  12.0,
#  12.333333333333334,
#  12.666666666666666,
#  13.0,
#  13.333333333333334,
# ...

# %%
df_train['Hour'] = new_col2
df_train
# Out:
#               Datetime  Temperature  Humidity  Zephyr  GeneralDiffuseFlows  \
# 0        1/1/2017 0:00        6.559     73.80   0.083                0.051
# 1        1/1/2017 0:20        6.313     74.50   0.080                0.062
# 2        1/1/2017 0:40        5.921     75.70   0.081                0.048
# 3        1/1/2017 1:00        5.641     77.70   0.080                0.048
# 4        1/1/2017 1:20        5.678     78.10   0.081                0.066
# ...                ...          ...       ...     ...                  ...
# 18340  9/12/2017 17:20       25.410     43.21   0.276              342.200
# 18341  9/12/2017 17:40       25.500     42.95   0.273              295.900
# 18342  9/12/2017 18:00       24.980     44.61   0.272              237.400
# 18343  9/12/2017 18:20       24.430     46.22   0.273              102.700
# 18344  9/12/2017 18:40       23.970     48.12   0.270              112.800
#
#        DiffuseFlows  PowerConsumption       Hour
# ...

# %%
df_test['Hour'] = new_col_t2
df_test
# Out:
#               Datetime  Temperature  Humidity  Zephyr  GeneralDiffuseFlows  \
# 0      9/12/2017 19:00       23.510     50.15   0.271               46.780
# 1      9/12/2017 19:20       22.970     52.65   0.273                9.520
# 2      9/12/2017 19:40       22.730     53.68   0.271                1.257
# 3      9/12/2017 20:00       22.370     54.65   0.269                0.080
# 4      9/12/2017 20:20       22.070     55.85   0.274                0.080
# ...                ...          ...       ...     ...                  ...
# 7858  12/30/2017 22:20        7.650     70.10   0.081                0.062
# 7859  12/30/2017 22:40        7.390     71.20   0.079                0.066
# 7860  12/30/2017 23:00        7.070     72.50   0.080                0.059
# 7861  12/30/2017 23:20        6.947     72.60   0.082                0.051
# 7862  12/30/2017 23:40        6.758     73.00   0.080                0.066
#
#       DiffuseFlows       Hour
# 0           49.950  19.000000
# ...

# %%
from datetime import datetime

# %%
dt = datetime.today()
dt.weekday()
# Out:
# 0

# %% [markdown]
# returns day of the week where 0 is monday and 6 is sunday

# %%
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# %%
# dt = datetime(df_train['Datetime'][0])
# dt.weekday()

# %% [markdown]
# ## hmmm ok

# %%
df_train['Datetime'][0]
# Out:
# '1/1/2017 0:00'

# %%
df_test['Datetime'][0]
# Out:
# '9/12/2017 19:00'

# %%
date_time_obj = datetime.strptime(df_train['Datetime'][0], '%m/%d/%Y %M:%S')
date_time_obj
# Out:
# datetime.datetime(2017, 1, 1, 0, 0)

# %%
date_time_obj2 = datetime.strptime(df_test['Datetime'][0], '%m/%d/%Y %M:%S')
date_time_obj2
# Out:
# datetime.datetime(2017, 9, 12, 0, 19)

# %%
day_of_week = []
for date in df_train['Datetime']:
    i = datetime.strptime(date, '%m/%d/%Y %H:%M').weekday()
    day_of_week.append(days[i])

# %%
day_of_week2 = []
for date in df_test['Datetime']:
    j = datetime.strptime(date, '%m/%d/%Y %H:%M').weekday()
    day_of_week2.append(days[j])

# %%
month = []
for date in df_train['Datetime']:
    m = datetime.strptime(date, '%m/%d/%Y %H:%M').month
    month.append(m)

df_train['Month'] = month

month = []
for date in df_test['Datetime']:
    m = datetime.strptime(date, '%m/%d/%Y %H:%M').month
    month.append(m)

df_test['Month'] = month

# %%
df_train.head()
# Out:
#         Datetime  Temperature  Humidity  Zephyr  GeneralDiffuseFlows  \
# 0  1/1/2017 0:00        6.559      73.8   0.083                0.051
# 1  1/1/2017 0:20        6.313      74.5   0.080                0.062
# 2  1/1/2017 0:40        5.921      75.7   0.081                0.048
# 3  1/1/2017 1:00        5.641      77.7   0.080                0.048
# 4  1/1/2017 1:20        5.678      78.1   0.081                0.066
#
#    DiffuseFlows  PowerConsumption      Hour  Month
# 0         0.119       34055.69620  0.000000      1
# 1         0.100       29128.10127  0.333333      1
# 2         0.085       27335.69620  0.666667      1
# 3         0.096       25998.98734  1.000000      1
# 4         0.141       24777.72152  1.333333      1

# %%
df_test.head()
# Out:
#           Datetime  Temperature  Humidity  Zephyr  GeneralDiffuseFlows  \
# 0  9/12/2017 19:00        23.51     50.15   0.271               46.780
# 1  9/12/2017 19:20        22.97     52.65   0.273                9.520
# 2  9/12/2017 19:40        22.73     53.68   0.271                1.257
# 3  9/12/2017 20:00        22.37     54.65   0.269                0.080
# 4  9/12/2017 20:20        22.07     55.85   0.274                0.080
#
#    DiffuseFlows       Hour  Month
# 0        49.950  19.000000      9
# 1         7.830  19.333333      9
# 2         1.093  19.666667      9
# 3         0.104  20.000000      9
# 4         0.089  20.333333      9

# %%
df_train['day_of_week'] = day_of_week

# %%
df_test['day_of_week'] = day_of_week2

# %%
df_train
# Out:
#               Datetime  Temperature  Humidity  Zephyr  GeneralDiffuseFlows  \
# 0        1/1/2017 0:00        6.559     73.80   0.083                0.051
# 1        1/1/2017 0:20        6.313     74.50   0.080                0.062
# 2        1/1/2017 0:40        5.921     75.70   0.081                0.048
# 3        1/1/2017 1:00        5.641     77.70   0.080                0.048
# 4        1/1/2017 1:20        5.678     78.10   0.081                0.066
# ...                ...          ...       ...     ...                  ...
# 18340  9/12/2017 17:20       25.410     43.21   0.276              342.200
# 18341  9/12/2017 17:40       25.500     42.95   0.273              295.900
# 18342  9/12/2017 18:00       24.980     44.61   0.272              237.400
# 18343  9/12/2017 18:20       24.430     46.22   0.273              102.700
# 18344  9/12/2017 18:40       23.970     48.12   0.270              112.800
#
#        DiffuseFlows  PowerConsumption       Hour  Month day_of_week
# ...

# %%
df_test
# Out:
#               Datetime  Temperature  Humidity  Zephyr  GeneralDiffuseFlows  \
# 0      9/12/2017 19:00       23.510     50.15   0.271               46.780
# 1      9/12/2017 19:20       22.970     52.65   0.273                9.520
# 2      9/12/2017 19:40       22.730     53.68   0.271                1.257
# 3      9/12/2017 20:00       22.370     54.65   0.269                0.080
# 4      9/12/2017 20:20       22.070     55.85   0.274                0.080
# ...                ...          ...       ...     ...                  ...
# 7858  12/30/2017 22:20        7.650     70.10   0.081                0.062
# 7859  12/30/2017 22:40        7.390     71.20   0.079                0.066
# 7860  12/30/2017 23:00        7.070     72.50   0.080                0.059
# 7861  12/30/2017 23:20        6.947     72.60   0.082                0.051
# 7862  12/30/2017 23:40        6.758     73.00   0.080                0.066
#
#       DiffuseFlows       Hour  Month day_of_week
# ...

# %%
# sns.pairplot(df_train, hue='Temperature', palette='coolwarm')

# %%
plt.scatter(df_train['Hour'], df_train['PowerConsumption'], c=df_train['Month'], cmap='coolwarm')
plt.colorbar()

# %%
mnth = 1
plt.scatter(df_train[df_train['Month'] == mnth]['day_of_week'], df_train[df_train['Month'] == mnth]['PowerConsumption'])

# %%
df_train.groupby(['day_of_week'])['GeneralDiffuseFlows'].mean().sort_values(ascending=False)
# Out:
# day_of_week
# Friday       212.898835
# Tuesday      209.196525
# Thursday     208.405945
# Wednesday    207.370892
# Monday       206.123682
# Saturday     205.877314
# Sunday       205.391783
# Name: GeneralDiffuseFlows, dtype: float64

# %%
my_dict = {'Monday': 3, 
           'Tuesday': 6, 
           'Wednesday': 4, 
           'Thursday': 5, 
           'Friday': 7, 
           'Saturday': 2, 
           'Sunday': 1}

df_train['day_of_week'].replace(my_dict, inplace=True)
df_test['day_of_week'].replace(my_dict, inplace=True)

df_train.head()
# Out:
#         Datetime  Temperature  Humidity  Zephyr  GeneralDiffuseFlows  \
# 0  1/1/2017 0:00        6.559      73.8   0.083                0.051
# 1  1/1/2017 0:20        6.313      74.5   0.080                0.062
# 2  1/1/2017 0:40        5.921      75.7   0.081                0.048
# 3  1/1/2017 1:00        5.641      77.7   0.080                0.048
# 4  1/1/2017 1:20        5.678      78.1   0.081                0.066
#
#    DiffuseFlows  PowerConsumption      Hour    Month  day_of_week
# 0         0.119       34055.69620  0.000000  January            1
# 1         0.100       29128.10127  0.333333  January            1
# 2         0.085       27335.69620  0.666667  January            1
# 3         0.096       25998.98734  1.000000  January            1
# 4         0.141       24777.72152  1.333333  January            1

# %%
my_dict = {1: 'January', 2: 'February', 3: 'March', 4: 'April', 5: 'May', 6: 'June', 7: 'July', 8: 'August', 9: 'September', 10: 'October', 11: 'November', 12: 'December'}

df_train['Month'].replace(my_dict, inplace=True)
df_test['Month'].replace(my_dict, inplace=True)
df_train
# Out:
#               Datetime  Temperature  Humidity  Zephyr  GeneralDiffuseFlows  \
# 0        1/1/2017 0:00        6.559     73.80   0.083                0.051
# 1        1/1/2017 0:20        6.313     74.50   0.080                0.062
# 2        1/1/2017 0:40        5.921     75.70   0.081                0.048
# 3        1/1/2017 1:00        5.641     77.70   0.080                0.048
# 4        1/1/2017 1:20        5.678     78.10   0.081                0.066
# ...                ...          ...       ...     ...                  ...
# 18340  9/12/2017 17:20       25.410     43.21   0.276              342.200
# 18341  9/12/2017 17:40       25.500     42.95   0.273              295.900
# 18342  9/12/2017 18:00       24.980     44.61   0.272              237.400
# 18343  9/12/2017 18:20       24.430     46.22   0.273              102.700
# 18344  9/12/2017 18:40       23.970     48.12   0.270              112.800
#
# ...

# %%
plt.scatter(df_train['Month'], df_train['GeneralDiffuseFlows'])

# %%
df_train.groupby(['Month'])['GeneralDiffuseFlows'].median().sort_values(ascending=False)
# Out:
# Month
# July         121.650
# June          97.300
# May           73.250
# August        44.715
# September     27.340
# April         20.015
# March          3.008
# February       0.091
# January        0.084
# Name: GeneralDiffuseFlows, dtype: float64

# %%
# rank = {'August': 12,
#         'July': 11,
#         'June': 10,
#         'September': 9,
#         'October': 8,
#         'May': 7,
#         'April': 6,
#         'March': 5,
#         'November': 4,
#         'December': 3,
#         'January': 2,
#         'February': 1,}

rank = {'January': 1, 
        'February': 5, 
        'March': 5, 
        'April': 6, 
        'May': 10, 
        'June': 11, 
        'July': 12, 
        'August': 9, 
        'September': 8, 
        'October': 4, 
        'November': 3, 
        'December': 2}


df_train['Month'].replace(rank, inplace=True)
df_test['Month'].replace(rank, inplace=True)

# %%
df_test
# Out:
#               Datetime  Temperature  Humidity  Zephyr  GeneralDiffuseFlows  \
# 0      9/12/2017 19:00       23.510     50.15   0.271               46.780
# 1      9/12/2017 19:20       22.970     52.65   0.273                9.520
# 2      9/12/2017 19:40       22.730     53.68   0.271                1.257
# 3      9/12/2017 20:00       22.370     54.65   0.269                0.080
# 4      9/12/2017 20:20       22.070     55.85   0.274                0.080
# ...                ...          ...       ...     ...                  ...
# 7858  12/30/2017 22:20        7.650     70.10   0.081                0.062
# 7859  12/30/2017 22:40        7.390     71.20   0.079                0.066
# 7860  12/30/2017 23:00        7.070     72.50   0.080                0.059
# 7861  12/30/2017 23:20        6.947     72.60   0.082                0.051
# 7862  12/30/2017 23:40        6.758     73.00   0.080                0.066
#
#       DiffuseFlows       Hour  Month  day_of_week
# ...

# %%
df_train.describe()
# Out:
#         Temperature      Humidity        Zephyr  GeneralDiffuseFlows  \
# count  18345.000000  18345.000000  18345.000000         18345.000000
# mean      19.239162     67.661446      1.997935           207.882264
# std        6.181693     16.079679      2.357637           285.898210
# min        3.441000     11.570000      0.050000             0.004000
# 25%       14.340000     57.380000      0.077000             0.066000
# 50%       19.160000     69.490000      0.086000            17.880000
# 75%       24.040000     81.400000      4.913000           384.600000
# max       40.010000     93.600000      4.978000          1163.000000
#
#        DiffuseFlows  PowerConsumption          Hour         Month  \
# count  18345.000000      18345.000000  18345.000000  18345.000000
# mean      86.710306      32954.219796     11.825566      7.423058
# std      136.137228       7251.530496      6.925103      3.435005
# min        0.033000      13920.000000      0.000000      1.000000
# ...

# %%
df_train.columns
# Out:
# Index(['Datetime', 'Temperature', 'Humidity', 'Zephyr', 'GeneralDiffuseFlows',
#        'DiffuseFlows', 'PowerConsumption', 'Hour', 'Month', 'day_of_week'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler

cols = ['Temperature', 'Humidity', 'Zephyr', 'GeneralDiffuseFlows', 'DiffuseFlows', 'Hour', 'Month', 'day_of_week']

for column in cols:
    scaler = MinMaxScaler()
    df_train[[column]] = scaler.fit_transform(df_train[[column]])
    df_test[[column]] = scaler.fit_transform(df_test[[column]])

# scaler_x = MinMaxScaler()
# df_train[['Temperature', 'Humidity', 'Zephyr', 'GeneralDiffuseFlows',
#               'DiffuseFlows', 'Hour', 'Month', 'day_of_week']] = scaler_x.fit_transform(df_train[['Temperature', 'Humidity', 'Zephyr', 'GeneralDiffuseFlows',
#                                                                                     'DiffuseFlows', 'Hour', 'Month', 'day_of_week']])

# %%
scaler_y = MinMaxScaler()
df_train[['PowerConsumption']] = scaler_y.fit_transform(df_train[['PowerConsumption']])

# %%
df_train.describe()
# Out:
#         Temperature      Humidity        Zephyr  GeneralDiffuseFlows  \
# count  18345.000000  18345.000000  18345.000000         18345.000000
# mean       0.432010      0.683792      0.395279             0.178744
# std        0.169042      0.196022      0.478417             0.245829
# min        0.000000      0.000000      0.000000             0.000000
# 25%        0.298039      0.558454      0.005479             0.000053
# 50%        0.429845      0.706083      0.007305             0.015371
# 75%        0.563291      0.851274      0.986810             0.330694
# max        1.000000      1.000000      1.000000             1.000000
#
#        DiffuseFlows  PowerConsumption          Hour         Month  \
# count  18345.000000      18345.000000  18345.000000  18345.000000
# mean       0.095992          0.497180      0.499672      0.583914
# std        0.150767          0.189412      0.292610      0.312273
# min        0.000000          0.000000      0.000000      0.000000
# ...

# %%
df_test.describe()
# Out:
#        Temperature     Humidity       Zephyr  GeneralDiffuseFlows  \
# count  7863.000000  7863.000000  7863.000000          7863.000000
# mean      0.466335     0.689796     0.314220             0.147143
# std       0.165640     0.174482     0.404200             0.229493
# min       0.000000     0.000000     0.000000             0.000000
# 25%       0.354231     0.576391     0.002954             0.000057
# 50%       0.486412     0.701345     0.003997             0.000108
# 75%       0.580752     0.835863     0.843614             0.246499
# max       1.000000     1.000000     1.000000             1.000000
#
#        DiffuseFlows         Hour        Month  day_of_week
# count   7863.000000  7863.000000  7863.000000  7863.000000
# mean       0.057713     0.500766     0.307135     0.503688
# std        0.102558     0.292988     0.334041     0.332570
# min        0.000000     0.000000     0.000000     0.000000
# 25%        0.000120     0.253521     0.000000     0.166667
# ...

# %%
# df_test[['Temperature', 'Humidity', 'Zephyr', 'GeneralDiffuseFlows',
#        'DiffuseFlows', 'Hour', 'Month', 'day_of_week']] = scaler_x.fit_transform(df_test[['Temperature', 'Humidity', 'Zephyr', 'GeneralDiffuseFlows',
#                                                                              'DiffuseFlows', 'Hour', 'Month', 'day_of_week']])

# %%
# df_train[['PowerConsumption', 'Hour']] = scaler.fit_transform(df_train[['PowerConsumption', 'Hour']])

# %%
df_train.columns
# Out:
# Index(['Datetime', 'Temperature', 'Humidity', 'Zephyr', 'GeneralDiffuseFlows',
#        'DiffuseFlows', 'PowerConsumption', 'Hour', 'Month', 'day_of_week'],
#       dtype='object')

# %%
df_test.columns
# Out:
# Index(['Datetime', 'Temperature', 'Humidity', 'Zephyr', 'GeneralDiffuseFlows',
#        'DiffuseFlows', 'Hour', 'Month', 'day_of_week'],
#       dtype='object')

# %%
final_df = df_train[['Month', 'day_of_week', 'Hour', 'Temperature', 'Humidity', 'Zephyr', 'GeneralDiffuseFlows', 'DiffuseFlows', 'PowerConsumption']]
df_test = df_test[['Month', 'day_of_week', 'Hour', 'Temperature', 'Humidity', 'Zephyr', 'GeneralDiffuseFlows', 'DiffuseFlows']]
final_df.head()
# Out:
#    Month  day_of_week      Hour  Temperature  Humidity    Zephyr  \
# 0    0.0          0.0  0.000000     0.085263  0.758625  0.006696
# 1    0.0          0.0  0.014085     0.078536  0.767158  0.006088
# 2    0.0          0.0  0.028169     0.067817  0.781787  0.006291
# 3    0.0          0.0  0.042254     0.060160  0.806168  0.006088
# 4    0.0          0.0  0.056338     0.061172  0.811045  0.006291
#
#    GeneralDiffuseFlows  DiffuseFlows  PowerConsumption
# 0             0.000040      0.000095          0.525950
# 1             0.000050      0.000074          0.397240
# 2             0.000038      0.000058          0.350422
# 3             0.000038      0.000070          0.315507
# 4             0.000053      0.000120          0.283607

# %%
df_test.head()
# Out:
#    Month  day_of_week      Hour  Temperature  Humidity    Zephyr  \
# 0    1.0     0.833333  0.802817     0.666995  0.448970  0.036316
# 1    1.0     0.833333  0.816901     0.647986  0.479822  0.036664
# 2    1.0     0.833333  0.830986     0.639538  0.492534  0.036316
# 3    1.0     0.833333  0.845070     0.626866  0.504505  0.035969
# 4    1.0     0.833333  0.859155     0.616305  0.519314  0.036838
#
#    GeneralDiffuseFlows  DiffuseFlows
# 0             0.055349      0.059880
# 1             0.011253      0.009375
# 2             0.001475      0.001297
# 3             0.000082      0.000112
# 4             0.000082      0.000094

# %%
# sns.pairplot(final_df, palette='Set1', diag_kind='hist')

# %%
# test train split
from sklearn.model_selection import train_test_split

X = final_df.drop('PowerConsumption', axis=1)
y = final_df['PowerConsumption']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %%
y.isnull().sum()
# Out:
# 0

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

transformation_step = ColumnTransformer([('trf',OneHotEncoder(sparse=False,drop='first'),['day_of_week'])], remainder='passthrough')

# %%
from sklearn.ensemble import RandomForestRegressor

# pipe_tree = Pipeline(steps=[
#     ('step1', transformation_step),
#     ('step2', RandomForestRegressor())
# ])

pipe_tree = Pipeline(steps=[
    ('step1', RandomForestRegressor())
])

# %%
pipe_tree.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('step1', RandomForestRegressor())])

# %%
pipe_tree.score(X_test, y_test)
# Out:
# 0.9666075031308482

# %%
# pipe_lin.predict(final_df2)
y_pred = pipe_tree.predict(df_test)
y_pred = scaler_y.inverse_transform(y_pred.reshape(-1,1))
y_pred
# Out:
# array([[41698.0020203],
#        [46654.0602644],
#        [48584.5435962],
#        ...,
#        [34643.9308172],
#        [31735.6976828],
#        [29719.628635 ]])

# %%
from xgboost import XGBRegressor

# pipe_xg = Pipeline(steps=[
#     ('step1', transformation_step),
#     ('step2', XGBRegressor(
#             learning_rate = 0.3,
#             objective='reg:linear',
#     ))
# ])

pipe_xg = Pipeline(steps=[
    ('step1', XGBRegressor(
            learning_rate = 0.3,
            objective='reg:linear',
            n_estimators=1000,
    ))
])

# %%
pipe_xg.fit(X_train, y_train)
# Out:
# [01:40:02] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# Pipeline(steps=[('step1',
#                  XGBRegressor(base_score=None, booster=None, callbacks=None,
#                               colsample_bylevel=None, colsample_bynode=None,
#                               colsample_bytree=None, early_stopping_rounds=None,
#                               enable_categorical=False, eval_metric=None,
#                               feature_types=None, gamma=None, gpu_id=None,
#                               grow_policy=None, importance_type=None,
#                               interaction_constraints=None, learning_rate=0.3,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
# ...

# %%
pipe_xg.score(X_test, y_test)
# Out:
# 0.9717708297079725

# %%
y_pred_xg = pipe_xg.predict(df_test)
y_pred_xg = scaler_y.inverse_transform(y_pred_xg.reshape(-1,1))
y_pred_xg
# Out:
# array([[45949.918],
#        [48167.38 ],
#        [49470.2  ],
#        ...,
#        [36928.27 ],
#        [33718.65 ],
#        [32907.97 ]], dtype=float32)

# %%
sample = pd.read_csv('./sample_submission.csv')

# %%
sumbission_df = pd.DataFrame({'Datetime': sample['Datetime'], 'PowerConsumption': y_pred_xg.reshape(-1)})

# %%
sumbission_df.to_csv('submission_16.csv', index=False)

# %%
sumbission_df.head(-10)
# Out:
#               Datetime  PowerConsumption
# 0      9/12/2017 19:00      39288.343750
# 1      9/12/2017 19:20      44013.125000
# 2      9/12/2017 19:40      45160.949219
# 3      9/12/2017 20:00      44076.750000
# 4      9/12/2017 20:20      44300.628906
# ...                ...               ...
# 7848  12/30/2017 19:00      41293.546875
# 7849  12/30/2017 19:20      41509.246094
# 7850  12/30/2017 19:40      40669.855469
# 7851  12/30/2017 20:00      41057.496094
# 7852  12/30/2017 20:20      41392.214844
#
# [7853 rows x 2 columns]

# %%
from sklearn.linear_model import LinearRegression

linreg = LinearRegression()

# %%
linreg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
linreg.score(X_test, y_test)
# Out:
# 0.6249364279389977
